# %%
import pandas as pd
import bs4
from bs4 import BeautifulSoup
import requests
import html5lib
import re

# %%
s = open("rt-wts.html", encoding="ISO-8859-1").read()
parser = BeautifulSoup(s, 'html5lib')
films = parser.find_all("li", class_="bottom_divider media")

# %%
save = {}

for film in films:
    name = film.find("a")["title"]
    save[name] = {}
    
    _score = film.find("span", class_="tMeterScore")
    if _score is None:
        score = 0
    else:
        score = int(_score.string.split("%")[0])
        
    save[name]["Score"] = score

    r = film.find("p", class_="subtle small").text.split(" -")[1]
    if "," in r:
        r = r.split(",")[1]

    hrs_match = re.match("(?:\d*\.)?\d+ hr", r)
    mins_match = re.search("(?:\d*\.)?\d+ min", r)

    if hrs_match is not None:
        hrs = hrs_match.group().split()[0]
    else:
        hrs = 0

    if mins_match is not None:
        mins = mins_match.group().split()[0]
    else:
        mins = 0

    save[name]["Runtime"] = (int(hrs) * 60) + int(mins)
    #print(save[name]["Runtime"])

# %%
thats_better = pd.DataFrame.from_dict(save, orient="index")
thats_better.sort_values("Runtime", ascending=True)
# Out:
#                                                   Score  Runtime
# Ghostbusters                                          0        0
# The Little Prince                                    94        0
# Suicide Squad                                         0        0
# Rogue One: A Star Wars Story                          0        0
# Despicable Me 3                                       0        0
# Pirates of the Caribbean: Dead Men Tell No Tales      0        0
# Kubo and the Two Strings                              0        0
# Independence Day: Resurgence                          0        0
# Fantastic Beasts and Where to Find Them               0        0
# Dunkirk                                               0        0
# South Park: Imaginationland: The Movie                0       67
# The Ghost Writer                                     83       68
# Adieu au langage (Goodbye to Language)               87       70
# The Girlfriend Experience                            66       77
# Yosemite                                             75       82
# Cloverfield                                          77       84
# The King and the Mockingbird                        100       85
# Chicken Run                                          97       85
# The Campaign                                         64       86
# Liar Liar                                            81       87
# Stand by Me                                          91       87
# Lucy                                                 67       89
# Blue Ruin                                            96       90
# Rams (Hrútar)                                        96       90
# Good Night, And Good Luck                            93       90
# A Field in England                                   87       90
# A Hologram for the King                              64       90
# Masterminds                                           0       90
# The Bicycle Thief                                    98       90
# Minions                                              55       91
# ...                                                 ...      ...
# Mission: Impossible Ghost Protocol                   93      132
# 12 Years a Slave                                     96      134
# Bridge of Spies                                      91      135
# Rosemary\'s Baby                                     99      136
# Unbroken                                             51      137
# The Hunger Games: Mockingjay - Part 2                70      137
# Close Encounters of the Third Kind                   96      137
# Godzilla                                             74      138
# Flight                                               77      138
# L.A. Confidential                                    99      138
# Fight Club                                           79      139
# Apollo 13                                            95      140
# Letters from Iwo Jima                                91      142
# Come and See (Idi i smotri)                          95      142
# Blood Diamond                                        62      143
# Cinderella Man                                       80      144
# Gone Girl                                            88      145
# Das Boot                                             98      145
# The Shining                                          89      145
# War Horse                                            76      146
# Lincoln                                              90      149
# The Town                                             94      151
# Amadeus                                              95      158
# The Bridge on the River Kwai                         94      161
# Munich                                               78      163
# Boyhood                                              98      165
# Gangs of New York                                    75      166
# Pirates of the Caribbean: At Worlds End              45      169
# A Bridge Too Far                                     73      175
# Braveheart                                           78      177
#
# [139 rows x 2 columns]

# %%
released = thats_better[(thats_better["Runtime"] > 0) & (thats_better["Score"] > 0)]

# %%
released
# Out:
#                                                     Score  Runtime
# 12 Years a Slave                                       96      134
# 127 Hours                                              93       94
# 1408                                                   79       94
# 21 Jump Street                                         85      109
# A Bridge Too Far                                       73      175
# A Field in England                                     87       90
# A Hologram for the King                                64       90
# A River Runs Through It                                83      123
# Adieu au langage (Goodbye to Language)                 87       70
# Alien                                                  97      117
# All Is Lost                                            94      105
# Amadeus                                                95      158
# American Graffiti                                      95      113
# Animal Kingdom                                         95      112
# Apollo 13                                              95      140
# Big Fish                                               77      125
# Birdman                                                91      119
# Black Mass                                             75      120
# Black Sea                                              80      115
# Blood Diamond                                          62      143
# Blue Ruin                                              96       90
# Boyhood                                                98      165
# Boyz n the Hood                                        96      112
# Bram Stoker\'s Dracula                                 79      130
# Braveheart                                             78      177
# Bridge of Spies                                        91      135
# Canvas                                                 78      100
# Chicken Run                                            97       85
# Cinderella Man                                         80      144
# Close Encounters of the Third Kind                     96      137
# ...                                                   ...      ...
# The Boy in the Striped Pajamas (The Boy in the ...     63      106
# The Bridge on the River Kwai                           94      161
# The Butterfly Effect                                   33      113
# The Campaign                                           64       86
# The Central Park Five                                  93      120
# The Changeling                                         76      114
# The Double                                             82       93
# The Fugitive                                           96      130
# The Ghost Writer                                       83       68
# The Girlfriend Experience                              66       77
# The Gods Must Be Crazy                                 95      109
# The Hunger Games: Mockingjay - Part 2                  70      137
# The Jungle Book                                        94      111
# The King and the Mockingbird                          100       85
# The Last of the Mohicans                               94      114
# The Omen                                               86      111
# The Painted Veil                                       74      124
# The Peanuts Movie                                      87       92
# The Searchers                                         100      119
# The Shining                                            89      145
# The Theory of Everything                               79      123
# The Town                                               94      151
# This Is the End                                        83      107
# Touched With Fire                                      68      106
# Unbroken                                               51      137
# War Horse                                              76      146
# Whiskey Tango Foxtrot                                  65      111
# World War Z                                            68      116
# Yosemite                                               75       82
# Zootopia                                               98      108
#
# [124 rows x 2 columns]
